# %%
# %%time
import xarray as xr
import numpy as np

varname = 'ivt' ## 700z or ivt
start_year = 2002
end_year = 2023

for i, yr in enumerate(range(start_year, end_year+1)):
    print(yr)
    path_to_data = '/expanse/nfs/cw3e/cwp140/downloads/ERA5/'
    fname = path_to_data + '{0}/6hr/era5_namerica_025dg_6hr_{0}_{1}.nc'.format(varname, yr)
    
    ds = xr.open_dataset(fname)

    if varname == 'ivt':
        ## rename ivtv and ivtu
        ds = ds.rename({'p71.162': 'ivtu', 'p72.162': 'ivtv'})
        ## add ivt magnitude
        ds = ds.assign(ivt=np.sqrt(ds['ivtu']**2 + ds['ivtv']**2))

    ds = ds.resample(time='1D').mean()
    
    out_fname = path_to_data + '{0}/daily/era5_namerica_025dg_daily_{0}_{1}.nc'.format(varname, yr)
    ds.to_netcdf(path=out_fname, mode = 'w', format='NETCDF4')
# Out:
# 2002
# ERROR 1: PROJ: proj_create_from_database: Open of /home/dnash/miniconda3/envs/SEAK-impacts/share/proj failed
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023
# CPU times: user 37.2 s, sys: 18.7 s, total: 55.9 s
# Wall time: 1min 29s

# %%
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 401, latitude: 201, time: 365)
# Coordinates:
#   * longitude  (longitude) float32 -170.0 -169.8 -169.5 ... -70.5 -70.25 -70.0
#   * latitude   (latitude) float32 60.0 59.75 59.5 59.25 ... 10.5 10.25 10.0
#   * time       (time) datetime64[ns] 2001-01-01 2001-01-02 ... 2001-12-31
# Data variables:
#     ivtv       (time, latitude, longitude) float32 4.063 3.854 ... -3.512 14.72
#     ivtu       (time, latitude, longitude) float32 -18.37 -17.33 ... -59.3
#     ivt        (time, latitude, longitude) float32 23.16 21.72 ... 57.46 62.95
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-07-10 21:01:09 GMT by grib_to_netcdf-2.28.1: /opt/ecmw...

# %%
filename_pattern = '/expanse/nfs/cw3e/cwp140/downloads/ERA5/700z/daily/era5_namerica_025dg_daily_*.nc'

ds = xr.open_mfdataset(filename_pattern,
                       engine='netcdf4',
                       combine='by_coords')
ds
# Out:
# <xarray.Dataset>
# Dimensions:    (longitude: 401, latitude: 201, time: 8766)
# Coordinates:
#   * longitude  (longitude) float32 -170.0 -169.8 -169.5 ... -70.5 -70.25 -70.0
#   * latitude   (latitude) float32 60.0 59.75 59.5 59.25 ... 10.5 10.25 10.0
#   * time       (time) datetime64[ns] 2000-01-01 2000-01-02 ... 2023-12-31
# Data variables:
#     z          (time, latitude, longitude) float32 dask.array<chunksize=(366, 201, 401), meta=np.ndarray>
# Attributes:
#     Conventions:  CF-1.6
#     history:      2024-07-10 18:32:43 GMT by grib_to_netcdf-2.28.1: /opt/ecmw...
